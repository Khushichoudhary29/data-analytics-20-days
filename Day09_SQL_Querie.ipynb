# %% [markdown]
# 📅 DAY 9 — SQL FOR DATA ANALYSTS (FOUNDATION)

# %% [markdown]
# 🎯 DAY 9 GOAL
#
# Write basic SQL queries
#
# Filter, sort, aggregate data
#
# Translate business questions → SQL

# %% [markdown]
# 📊 CREATE TABLE
#
# CREATE TABLE sales (
#     OrderID INT,
#     Region TEXT,
#     Product TEXT,
#     Category TEXT,
#     Sales INT,
#     Quantity INT
# );
#
#
# Insert data:
#
# INSERT INTO sales VALUES
# (1001,'North','Phone','Electronics',15000,2),
# (1002,'South','Laptop','Electronics',55000,1),
# (1003,'East','Chair','Furniture',7000,3),
# (1004,'West','Table','Furniture',12000,2),
# (1005,'North','Phone','Electronics',15000,1),
# (1006,'South','Chair','Furniture',7000,2),
# (1007,'East','Laptop','Electronics',55000,1),
# (1008,'West','Phone','Electronics',15000,2);
#
# 🧪 SECTION 1: BASIC QUERIES
# SELECT * FROM sales;
#
# SELECT Region, Sales FROM sales;
#
# 🧪 SECTION 2: FILTERING (WHERE)
# SELECT * FROM sales WHERE Category = 'Electronics';
#
# SELECT * FROM sales WHERE Sales > 20000;
#
# 🧪 SECTION 3: SORTING (ORDER BY)
# SELECT * FROM sales ORDER BY Sales DESC;
#
# SELECT * FROM sales ORDER BY Quantity ASC;
#
# 🧪 SECTION 4: AGGREGATION (CORE PART)
# SELECT Region, SUM(Sales) AS Total_Sales
# FROM sales
# GROUP BY Region;
#
# SELECT Category, AVG(Sales) AS Avg_Sales
# FROM sales
# GROUP BY Category;
#
# 🧪 SECTION 5: HAVING (MOST STUDENTS FAIL HERE)
# SELECT Region, SUM(Sales) AS Total_Sales
# FROM sales
# GROUP BY Region
# HAVING SUM(Sales) > 30000;

# %% [markdown]
# ![Screenshot 2025-12-21 153112.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-12-21 153208.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
